# %% [markdown]
# ### Analysis of Data Science Compared to All Industries
# Using national_M2022_dl.csv

# %% [markdown]
# Imports

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Loading CSV

# %%
# Relative path from script to CSV
csv_path = "../../data/national_M2022_dl.csv"

# Load the CSV

df = pd.read_csv(csv_path)

# %% [markdown]
# Analysis
